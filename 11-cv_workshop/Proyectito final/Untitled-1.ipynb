# %%
import numpy as np  
import matplotlib.pyplot as plt 
import cv2
img_chunga = cv2.imread("/Users/miguelopez/Desktop/Machine Learning_2/cv_workshop/Proyectito final/imagenes/perro.jpg")
plt.imshow(img_chunga)
