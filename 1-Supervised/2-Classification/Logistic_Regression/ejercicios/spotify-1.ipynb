# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('/Users/miguelopez/Downloads/archive/spotify_songs.csv',sep=',')

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
# distribution
df['tempo'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['tempo'].describe()
# Out:
# count    32833.000000
# mean       120.881132
# std         26.903624
# min          0.000000
# 25%         99.960000
# 50%        121.984000
# 75%        133.918000
# max        239.440000
# Name: tempo, dtype: float64

# %% [markdown]
# 'average'  tempo = moderately fast.
#
#
# The minimum = 0 bpm while the max = 239.44 bpm = wide range
#
# 25% below 99.96 = "slow" songs.
#
# 50% < 121.984 bpm.
#
# 75% < 133.92 bpm. Only 25% > this tempo.
#
#
#
# distribution centered around a moderately fast tempo of ~120 bpm.
#
# There is good range of tempos from very slow to very fast.
#
#  right-skewed, with more songs in the slow-to-medium tempo range.
#
# There are relatively few very fast or very slow outliers.

# %%
fast_songs = df[df['tempo'] > 120]
fast_songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# 5  7fvUMiyapMsRRxr07cU8Ef  Beautiful People (feat. Khalid) - Jack Wins Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 5        Ed Sheeran                67  2yiy9cd2QktrNvWC2EUi0k
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
# range 

'''no relationship between
 tempo and popularity.'''

df.corr()['tempo'].sort_values()
# Out:
# /var/folders/m8/hp9mxxbj6dv9x3px18fy22_r0000gn/T/ipykernel_8241/2984325962.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['tempo'].sort_values()
# danceability       -0.184084
# acousticness       -0.112724
# valence            -0.025732
# key                -0.013370
# track_popularity   -0.005378
# duration_ms        -0.001412
# mode                0.014329
# liveness            0.021018
# instrumentalness    0.023335
# speechiness         0.044603
# loudness            0.093767
# energy              0.149951
# tempo               1.000000
# Name: tempo, dtype: float64

# %%
import seaborn as sns

corr = df[['tempo','track_popularity']].corr()

# Generate heatmap
sns.heatmap(corr, 
            xticklabels=corr.columns,
            yticklabels=corr.columns)

plt.title('Variable Correlations')
plt.show()

# %%
# Feature eng.
bins = [0, 100, 130, 160]
labels = ['slow', 'medium', 'fast']
